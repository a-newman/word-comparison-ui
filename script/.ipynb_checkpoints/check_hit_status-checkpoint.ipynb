# %%
from boto3 import client
import json
import copy

with open('../config.json', 'r') as f:
    config = json.loads(f.read())['hitCreation']

if config['production']:
    endpoint_url = 'https://mturk-requester.us-east-1.amazonaws.com'
else:
    endpoint_url = 'https://mturk-requester-sandbox.us-east-1.amazonaws.com'
    
cl = client('mturk', region_name='us-east-1', endpoint_url=endpoint_url)

# %%
def create_hit(task):
    quals = [
       {
           'QualificationTypeId': '00000000000000000071',
           'Comparator': 'EqualTo',
           'LocaleValues': [{
               'Country': 'US',
           }],
       },
       {
           'QualificationTypeId': '000000000000000000L0',
           'Comparator': 'GreaterThanOrEqualTo',
           'IntegerValues': [
               95
           ],
       },
    ]

    questionText = "<ExternalQuestion xmlns=\"http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/"
    questionText += "2006-07-14/ExternalQuestion.xsd\">\n<ExternalURL>" + task['taskUrl']
    questionText += "</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>"

    response = cl.create_hit(
        MaxAssignments=task['numAssignments'],
        AutoApprovalDelayInSeconds=604800,
        LifetimeInSeconds=task['lifetime'],
        AssignmentDurationInSeconds=task['duration'],
        Reward=task['rewardAmount'],
        Title=task['title'],
        Keywords=task['keywords'],
        Description=task['description'],
        Question=questionText,
        QualificationRequirements=quals,
    )

    print(response)

# %% [markdown]
# # JUST TO CREATE HIT

# %%
if config['variants']: 
    print("creating " + str(len(config['variants'])) + " variants")
    for var in config['variants']: 
        task = copy.deepcopy(config)
        task.update(var)
        create_hit(task)
else: 
  print("creating " + str(config['numTasks']) + " tasks")
  for i in range(config['numTasks']):
      create_hit(config)

# %%
hits = cl.list_hits(MaxResults=9)['HITs']

hits
# Out:
# [{'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 37, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 37, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '3P520RYKCHF2UL892LPJA5TG0S35UP',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 9,
#   'NumberOfAssignmentsCompleted': 1,
#   'NumberOfAssignmentsPending': 0,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=8</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'},
#  {'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 37, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 37, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '329E6HTMSWBLDAGTUOXOPLMYK5E3K0',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 9,
#   'NumberOfAssignmentsCompleted': 1,
#   'NumberOfAssignmentsPending': 0,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=9</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'},
#  {'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 36, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 36, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '3JVP4ZJHDP1YQNR8BYUTA79EPP50IR',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 10,
#   'NumberOfAssignmentsCompleted': 0,
#   'NumberOfAssignmentsPending': 0,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=3</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'},
#  {'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 36, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 36, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '3J9UN9O9J31ULYBETGFTM8OE24U0J3',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 10,
#   'NumberOfAssignmentsCompleted': 0,
#   'NumberOfAssignmentsPending': 0,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=5</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'},
#  {'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 36, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 36, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '3VGZ74AYTGP4OOGTXQNAKWYZJ1ACG4',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 10,
#   'NumberOfAssignmentsCompleted': 0,
#   'NumberOfAssignmentsPending': 0,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=4</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'},
#  {'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 36, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 36, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '386T3MLZLN451HFV2CI2XIF0MT080R',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 9,
#   'NumberOfAssignmentsCompleted': 0,
#   'NumberOfAssignmentsPending': 0,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=6</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'},
#  {'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 36, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 36, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '3UQ1LLR26AHWH1XWO3OZRTDJFFBAL6',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 10,
#   'NumberOfAssignmentsCompleted': 0,
#   'NumberOfAssignmentsPending': 0,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=7</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'},
#  {'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 35, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 35, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '311HQEI8RSPY3OG2W13OPHMRTGD7ZV',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 9,
#   'NumberOfAssignmentsCompleted': 1,
#   'NumberOfAssignmentsPending': 0,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=2</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'},
#  {'AssignmentDurationInSeconds': 300,
#   'AutoApprovalDelayInSeconds': 604800,
#   'CreationTime': datetime.datetime(2018, 2, 9, 18, 7, 35, tzinfo=tzlocal()),
#   'Description': 'Given two words, select the one you think describes a larger change.',
#   'Expiration': datetime.datetime(2018, 2, 10, 18, 7, 35, tzinfo=tzlocal()),
#   'HITGroupId': '3EWXWOT87MLR7GYP451ZBIS24W7P52',
#   'HITId': '3UUIU9GZC5ENU8TK2GZ9597EHEW5TY',
#   'HITReviewStatus': 'NotReviewed',
#   'HITStatus': 'Assignable',
#   'HITTypeId': '3XJ5RHVJOBCS36D8T5MUWHH8C0IXL0',
#   'Keywords': 'words, comparison, ranking, fun, challenge, quick',
#   'MaxAssignments': 10,
#   'NumberOfAssignmentsAvailable': 9,
#   'NumberOfAssignmentsCompleted': 0,
#   'NumberOfAssignmentsPending': 1,
#   'QualificationRequirements': [{'Comparator': 'EqualTo',
#     'LocaleValues': [{'Country': 'US'}],
#     'QualificationTypeId': '00000000000000000071',
#     'RequiredToPreview': False},
#    {'Comparator': 'GreaterThanOrEqualTo',
#     'IntegerValues': [95],
#     'QualificationTypeId': '000000000000000000L0',
#     'RequiredToPreview': False}],
#   'Question': '<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd">\n<ExternalURL>https://people.csail.mit.edu/apnewman/word_comparison/?task=1</ExternalURL>\n  <FrameHeight>700</FrameHeight>\n</ExternalQuestion>',
#   'Reward': '0.20',
#   'Title': 'Which word is more intense?'}]

# %%
[hit['NumberOfAssignmentsAvailable'] for hit in hits]
# Out:
# [9, 9, 10, 10, 10, 9, 10, 9, 9]

# %%
import datetime

def summarize_hits(hits): 
    print(len(hits))
    ret = ""
    for hit in hits: 
        expiration = hit['Expiration'].replace(tzinfo=None)
        is_expired = expiration < datetime.datetime.now()
        description = ("Title: {title}\n" 
        "ID: {hid}\n"
        "\tAssignments left: {left}\n"
        "\tAssignments completed: {complete}\n"
        "\tAssignments pending: {pending}\n"
        "\tExpired: {exp}\n\n").format(
            title=hit['Title'], 
            hid=hit['HITId'], 
            left=hit['NumberOfAssignmentsAvailable'], 
            complete=hit['NumberOfAssignmentsCompleted'], 
            pending=hit['NumberOfAssignmentsPending'],
            exp=str(is_expired)
        )
        ret += description
    print(ret)

# %%
summarize_hits(hits)

pass
# Out:
# 9
# Title: Which word is more intense?
# ID: 3P520RYKCHF2UL892LPJA5TG0S35UP
# 	Assignments left: 9
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Which word is more intense?
# ID: 329E6HTMSWBLDAGTUOXOPLMYK5E3K0
# 	Assignments left: 9
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Which word is more intense?
# ID: 3JVP4ZJHDP1YQNR8BYUTA79EPP50IR
# 	Assignments left: 10
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Which word is more intense?
# ID: 3J9UN9O9J31ULYBETGFTM8OE24U0J3
# 	Assignments left: 10
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Which word is more intense?
# ID: 3VGZ74AYTGP4OOGTXQNAKWYZJ1ACG4
# 	Assignments left: 10
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Which word is more intense?
# ID: 386T3MLZLN451HFV2CI2XIF0MT080R
# 	Assignments left: 9
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Which word is more intense?
# ID: 3UQ1LLR26AHWH1XWO3OZRTDJFFBAL6
# 	Assignments left: 10
# 	Assignments completed: 0
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Which word is more intense?
# ID: 311HQEI8RSPY3OG2W13OPHMRTGD7ZV
# 	Assignments left: 9
# 	Assignments completed: 1
# 	Assignments pending: 0
# 	Expired: False
#
# Title: Which word is more intense?
# ID: 3UUIU9GZC5ENU8TK2GZ9597EHEW5TY
# 	Assignments left: 9
# 	Assignments completed: 0
# 	Assignments pending: 1
# 	Expired: False

# %%
def see_assignments(hits):
    ret = ""
    for hit in hits: 
        hid = hit['HITId']
        title =  hit['Title']
        name = "HIT %s: %s" % (hid, title)
        ret += name + "\n"
        assignments = cl.list_assignments_for_hit(HITId=hid)['Assignments']
        for a in assignments: 
            desc = "\tAssignment {aid}\n\t\tStatus: {status}\n".format(aid=a['AssignmentId'], status=a['AssignmentStatus'])
            ret += desc
    print(ret)

# %%
see_assignments(hits)

pass
# Out:
# HIT 3P520RYKCHF2UL892LPJA5TG0S35UP: Which word is more intense?
# 	Assignment 379J5II41PQ2UYC2UAWNCWZRBL4LE9
# 		Status: Approved
# HIT 329E6HTMSWBLDAGTUOXOPLMYK5E3K0: Which word is more intense?
# 	Assignment 3KOPY89HM9CTPA85253EDQI2G79J3E
# 		Status: Approved
# HIT 3JVP4ZJHDP1YQNR8BYUTA79EPP50IR: Which word is more intense?
# HIT 3J9UN9O9J31ULYBETGFTM8OE24U0J3: Which word is more intense?
# HIT 3VGZ74AYTGP4OOGTXQNAKWYZJ1ACG4: Which word is more intense?
# HIT 386T3MLZLN451HFV2CI2XIF0MT080R: Which word is more intense?
# 	Assignment 3VD82FOHKRYV3LVLBB6KEP3ILEXOC1
# 		Status: Approved
# HIT 3UQ1LLR26AHWH1XWO3OZRTDJFFBAL6: Which word is more intense?
# HIT 311HQEI8RSPY3OG2W13OPHMRTGD7ZV: Which word is more intense?
# 	Assignment 3DR23U6WE6OQDBK73JYEYN985YRTEL
# 		Status: Approved
# HIT 3UUIU9GZC5ENU8TK2GZ9597EHEW5TY: Which word is more intense?
# 	Assignment 35GMH2SV3FRA0JFZ72CF4D3L6QAOEU
# 		Status: Submitted

# %%
def approve_all(hits): 
    num_approved = 0
    for hit in hits: 
        assignments = cl.list_assignments_for_hit(HITId=hit['HITId'])['Assignments']
        for a in assignments: 
            if a['AssignmentStatus'] != 'Approved':
                print("Approving assignment")
                num_approved += 1
                cl.approve_assignment(AssignmentId=a['AssignmentId'])
    print("Approved %d assignments" % num_approved)

# %%
approve_all(hits)
# Out:
# Approving assignment
# Approved 1 assignments

# %%
from bs4 import BeautifulSoup as bs 
import pprint

def pretty_print(obj):
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(obj)

def get_assignment_content(hits, download_path="", should_print=False): 
    all_responses = []
    for hit in hits: 
        hitid = hit['HITId']
        assignments = cl.list_assignments_for_hit(HITId=hit['HITId'])['Assignments']
        for a in assignments:
            a_xml = a['Answer']
            #print(a_xml)
            soup = bs(a_xml, "lxml")
            answers = soup.find_all("answer")
            #print(answers)
            results = {'HITId': hitid}
            for ans in answers: 
                identifier = ans.find('questionidentifier').string
                answer = ans.find('freetext').string
                #print(identifier)
                #print(answer)
                try: 
                    results[identifier] = json.loads(answer)
                except:
                    results[identifier] = answer
            all_responses.append(results)
    if should_print: 
        pretty_print(all_responses)
    if download_path: 
        with open(download_path, 'w') as outfile: 
            json.dump(all_responses, outfile)
    return all_responses

# %%
get_assignment_content(hits, download_path='../results/results.json', should_print=True)

pass
# Out:
# [   {   'HITId': '3P520RYKCHF2UL892LPJA5TG0S35UP',
#         'feedback': None,
#         'results': {   'inputs': [   ['consistent', 'rapid'],
#                                      ['small', 'dramatic'],
#                                      ['gradual', 'small'],
#                                      ['huge', 'tiny'],
#                                      ['steep', 'sharp'],
#                                      ['steep', 'negligible'],
#                                      ['dramatic', 'gentle'],
#                                      ['modest', 'negligible'],
#                                      ['steep', 'noticeable'],
#                                      ['noticeable', 'substantial'],
#                                      ['negligible', 'slight'],
#                                      ['noticeable', 'gentle'],
#                                      ['huge', 'considerable'],
#                                      ['considerable', 'dramatic'],
#                                      ['sharp', 'substantial'],
#                                      ['negligible', 'modest'],
#                                      ['marginal', 'modest'],
#                                      ['marginal', 'negligible'],
#                                      ['consistent', 'rapid'],
#                                      ['marked', 'consistent'],
#                                      ['marked', 'small'],
#                                      ['marginal', 'sudden'],
#                                      ['large', 'small'],
#                                      ['considerable', 'sharp'],
#                                      ['consistent', 'huge'],
#                                      ['considerable', 'sudden'],
#                                      ['negligible', 'dramatic'],
#                                      ['gentle', 'marginal'],
#                                      ['small', 'big'],
#                                      ['gradual', 'dramatic']],
#                        'outputs': [   'rapid',
#                                       'dramatic',
#                                       'gradual',
#                                       'huge',
#                                       'steep',
#                                       'negligible',
#                                       'gentle',
#                                       'negligible',
#                                       'noticeable',
#                                       'substantial',
#                                       'slight',
#                                       'gentle',
#                                       'considerable',
#                                       'dramatic',
#                                       'substantial',
#                                       'modest',
#                                       'modest',
#                                       'negligible',
#                                       'rapid',
#                                       'consistent',
#                                       'small',
#                                       'sudden',
#                                       'small',
#                                       'sharp',
#                                       'huge',
#                                       'sudden',
#                                       'dramatic',
#                                       'marginal',
#                                       'big',
#                                       'dramatic',
#                                       'dramatic']},
#         'workerId': 'A1G9Z0CL537336'},
#     {   'HITId': '329E6HTMSWBLDAGTUOXOPLMYK5E3K0',
#         'feedback': 'great! ',
#         'results': {   'inputs': [   ['small', 'big'],
#                                      ['negligible', 'marked'],
#                                      ['noticeable', 'marked'],
#                                      ['slow', 'sudden'],
#                                      ['steep', 'marked'],
#                                      ['negligible', 'noticeable'],
#                                      ['dramatic', 'marked'],
#                                      ['large', 'significant'],
#                                      ['rapid', 'substantial'],
#                                      ['modest', 'slow'],
#                                      ['slow', 'modest'],
#                                      ['steady', 'marked'],
#                                      ['substantial', 'sudden'],
#                                      ['sharp', 'rapid'],
#                                      ['huge', 'tiny'],
#                                      ['marked', 'large'],
#                                      ['gentle', 'significant'],
#                                      ['marginal', 'significant'],
#                                      ['large', 'marked'],
#                                      ['slow', 'sudden'],
#                                      ['marked', 'huge'],
#                                      ['substantial', 'significant'],
#                                      ['significant', 'noticeable'],
#                                      ['large', 'gradual'],
#                                      ['large', 'consistent'],
#                                      ['rapid', 'marked'],
#                                      ['negligible', 'sharp'],
#                                      ['slow', 'marginal'],
#                                      ['dramatic', 'noticeable'],
#                                      ['rapid', 'slow']],
#                        'outputs': [   'big',
#                                       'marked',
#                                       'marked',
#                                       'sudden',
#                                       'steep',
#                                       'noticeable',
#                                       'dramatic',
#                                       'large',
#                                       'rapid',
#                                       'modest',
#                                       'modest',
#                                       'marked',
#                                       'substantial',
#                                       'rapid',
#                                       'huge',
#                                       'large',
#                                       'significant',
#                                       'significant',
#                                       'large',
#                                       'sudden',
#                                       'huge',
#                                       'substantial',
#                                       'significant',
#                                       'large',
#                                       'large',
#                                       'rapid',
#                                       'sharp',
#                                       'marginal',
#                                       'dramatic',
#                                       'rapid',
#                                       'rapid']},
#         'workerId': 'A1G9Z0CL537336'},
#     {   'HITId': '386T3MLZLN451HFV2CI2XIF0MT080R',
#         'feedback': 'my feedback is here ',
#         'results': {   'inputs': [   ['slight', 'marginal'],
#                                      ['slight', 'gentle'],
#                                      ['small', 'negligible'],
#                                      ['steady', 'consistent'],
#                                      ['slow', 'dramatic'],
#                                      ['sharp', 'slow'],
#                                      ['small', 'negligible'],
#                                      ['sudden', 'large'],
#                                      ['gentle', 'marked'],
#                                      ['slow', 'significant'],
#                                      ['slow', 'considerable'],
#                                      ['modest', 'substantial'],
#                                      ['steep', 'gentle'],
#                                      ['small', 'big'],
#                                      ['huge', 'tiny'],
#                                      ['steady', 'marginal'],
#                                      ['slow', 'sharp'],
#                                      ['consistent', 'significant'],
#                                      ['large', 'gentle'],
#                                      ['consistent', 'substantial'],
#                                      ['significant', 'considerable'],
#                                      ['gentle', 'considerable'],
#                                      ['negligible', 'slow'],
#                                      ['modest', 'large'],
#                                      ['sudden', 'dramatic'],
#                                      ['sudden', 'slow'],
#                                      ['rapid', 'slight'],
#                                      ['steep', 'huge'],
#                                      ['modest', 'sharp'],
#                                      ['slight', 'slow']],
#                        'outputs': [   'slight',
#                                       'slight',
#                                       'small',
#                                       'steady',
#                                       'slow',
#                                       'sharp',
#                                       'small',
#                                       'sudden',
#                                       'gentle',
#                                       'slow',
#                                       'slow',
#                                       'modest',
#                                       'steep',
#                                       'small',
#                                       'huge',
#                                       'steady',
#                                       'slow',
#                                       'consistent',
#                                       'large',
#                                       'consistent',
#                                       'significant',
#                                       'gentle',
#                                       'negligible',
#                                       'modest',
#                                       'sudden',
#                                       'sudden',
#                                       'rapid',
#                                       'steep',
#                                       'modest',
#                                       'slight',
#                                       'slight']},
#         'workerId': 'A1G9Z0CL537336'},
#     {   'HITId': '311HQEI8RSPY3OG2W13OPHMRTGD7ZV',
#         'feedback': 'my feedback here',
#         'results': {   'inputs': [   ['marginal', 'rapid'],
#                                      ['small', 'substantial'],
#                                      ['modest', 'sudden'],
#                                      ['huge', 'tiny'],
#                                      ['slight', 'considerable'],
#                                      ['sudden', 'consistent'],
#                                      ['small', 'big'],
#                                      ['steep', 'significant'],
#                                      ['steep', 'slow'],
#                                      ['gradual', 'sudden'],
#                                      ['steady', 'gradual'],
#                                      ['noticeable', 'small'],
#                                      ['large', 'slow'],
#                                      ['huge', 'dramatic'],
#                                      ['considerable', 'negligible'],
#                                      ['considerable', 'marginal'],
#                                      ['steady', 'huge'],
#                                      ['slight', 'gradual'],
#                                      ['steady', 'gentle'],
#                                      ['small', 'considerable'],
#                                      ['gentle', 'steady'],
#                                      ['modest', 'gradual'],
#                                      ['modest', 'consistent'],
#                                      ['considerable', 'substantial'],
#                                      ['significant', 'dramatic'],
#                                      ['gentle', 'rapid'],
#                                      ['modest', 'gradual'],
#                                      ['huge', 'noticeable'],
#                                      ['small', 'sudden'],
#                                      ['slight', 'consistent']],
#                        'outputs': [   'marginal',
#                                       'small',
#                                       'modest',
#                                       'huge',
#                                       'slight',
#                                       'sudden',
#                                       'small',
#                                       'steep',
#                                       'steep',
#                                       'gradual',
#                                       'steady',
#                                       'noticeable',
#                                       'large',
#                                       'huge',
#                                       'considerable',
#                                       'considerable',
#                                       'steady',
#                                       'slight',
#                                       'steady',
#                                       'small',
#                                       'gentle',
#                                       'modest',
#                                       'modest',
#                                       'considerable',
#                                       'significant',
#                                       'gentle',
#                                       'modest',
#                                       'huge',
#                                       'small',
#                                       'slight',
#                                       'slight']},
#         'workerId': 'A1G9Z0CL537336'},
#     {   'HITId': '3UUIU9GZC5ENU8TK2GZ9597EHEW5TY',
#         'feedback': 'fb',
#         'results': {   'inputs': [   ['huge', 'gradual'],
#                                      ['steady', 'slow'],
#                                      ['slow', 'huge'],
#                                      ['gentle', 'consistent'],
#                                      ['substantial', 'marked'],
#                                      ['steep', 'steady'],
#                                      ['sudden', 'gentle'],
#                                      ['huge', 'slight'],
#                                      ['rapid', 'sudden'],
#                                      ['small', 'steep'],
#                                      ['small', 'big'],
#                                      ['consistent', 'sharp'],
#                                      ['dramatic', 'steady'],
#                                      ['marked', 'sudden'],
#                                      ['sudden', 'negligible'],
#                                      ['huge', 'tiny'],
#                                      ['noticeable', 'rapid'],
#                                      ['huge', 'sharp'],
#                                      ['marginal', 'substantial'],
#                                      ['huge', 'sharp'],
#                                      ['steady', 'noticeable'],
#                                      ['small', 'steep'],
#                                      ['marked', 'marginal'],
#                                      ['noticeable', 'large'],
#                                      ['gentle', 'sharp'],
#                                      ['gentle', 'huge'],
#                                      ['sharp', 'noticeable'],
#                                      ['significant', 'huge'],
#                                      ['sudden', 'steady'],
#                                      ['gentle', 'substantial']],
#                        'outputs': [   'huge',
#                                       'steady',
#                                       'slow',
#                                       'gentle',
#                                       'substantial',
#                                       'steep',
#                                       'sudden',
#                                       'huge',
#                                       'rapid',
#                                       'small',
#                                       'small',
#                                       'consistent',
#                                       'dramatic',
#                                       'marked',
#                                       'sudden',
#                                       'huge',
#                                       'noticeable',
#                                       'huge',
#                                       'marginal',
#                                       'huge',
#                                       'steady',
#                                       'small',
#                                       'marked',
#                                       'noticeable',
#                                       'gentle',
#                                       'gentle',
#                                       'sharp',
#                                       'significant',
#                                       'sudden',
#                                       'gentle',
#                                       'gentle']},
#         'task': 1,
#         'workerId': 'A1G9Z0CL537336'}]

# %%
# Out:
# []
